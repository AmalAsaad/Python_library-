# %%
 #avoiding loops
    #matplotlib>>big library
    #pypolt >> packae inside matplotlib  
    
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
x=np.linspace(0,5*np.pi, 10 )
y= np.cos(x)
##to drow tow fun in same plot
z=np.sin(x)
plt.plot(x,z)
plt.plot(x,y)
plt.xlabel("moo")
plt.ylabel("size")
plt.xlim(0 , 0.5*np.pi)
plt.plot(x,z,"b--", label="sine" , linewidth=7) #only dashes
plt.plot(x,y,"ro", label="cosine" ,linewidth=100)

plt.text(1,0,"maximum" )
plt.annotate("local",xy=(1,0.5),xytext=(0.3,0.5), arrowprops=dict(facecolor='black' ,shrink=0.5))
plt.gca()
plt.ticks_position('left')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-9466a9068a8f> in <module>()
#      21 plt.annotate("local",xy=(1,0.5),xytext=(0.3,0.5), arrowprops=dict(facecolor='black' ,shrink=0.5))
#      22 plt.gca()
# ---> 23 plt.ticks_position('left')
#      24
#      25
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ticks_position'

# %%
plt.subplot(211)
plt.plot(x,y)
plt.subplot(212)
plt.plot(x,z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-090047380817> in <module>()
#       3 plt.subplot(212)
#       4 plt.plot(x,z)
# ----> 5 plt.legend(frameon=true,loc=2)
#
# NameError: name 'true' is not defined

# %%
#sentax of oop

# %%
f =plt.figure
ax=f.add_subplot(111)
x=linespace()
y=
ax=plt
ax.setlabel
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-71bd997147a4> in <module>()
#       1 #sentax of oop
#       2 f =plt.figure
# ----> 3 ax=f.add_subplot(111)
#
# AttributeError: 'function' object has no attribute 'add_subplot'

# %%
def g (x,y):
    return np.exp(-((x-0.5)**2)/0.1**2 - ((y-0.5)**2)/0.2**2)
n=100
x=np.linspace(0,1,n)
xv, yv =np.meshgrid(x,y)
plt.imshow(g(x,y) ,origin="lower")
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-d75a65a42c19> in <module>()
#       4 x=np.linspace(0,1,n)
#       5 xv, yv =np.meshgrid(x,y)
# ----> 6 plt.imshow(g(x,y) ,origin="lower")
#       7 plt.colorbar()
#
# <ipython-input-43-d75a65a42c19> in g(x, y)
#       1 def g (x,y):
# ----> 2     return np.exp(-((x-0.5)**2)/0.1**2 - ((y-0.5)**2)/0.2**2)
#       3 n=100
#       4 x=np.linspace(0,1,n)
#       5 xv, yv =np.meshgrid(x,y)
#
# ValueError: operands could not be broadcast together with shapes (100,) (10,)

# %%
#histogram
plt.hist()
